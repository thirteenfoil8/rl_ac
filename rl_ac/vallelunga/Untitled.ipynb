# %%
import numpy as np
import pandas as pd
from numpy.core.umath_tests import inner1d
# Out:
# <ipython-input-1-daa461d6ac4a>:3: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
df=pd.read_csv('vallelunga.csv')
df.columns
# Out:
# Index(['Position_X', 'Position_Y', 'Position_Z', 'Length', 'SideLeft',
#        'SideRight', 'Radius', 'Speed', 'Brake', 'Camber', 'Direction', 'Grade',
#        'Normal_X', 'Normal_Y', 'Normal_Z', 'Forward_X', 'Forward_Y',
#        'Forward_Z', 'Tag', 'LagG_Obsolete'],
#       dtype='object')

# %%
df.Position_X.max()
# Out:
# 559.505310058594

# %%
df
# Out:
#       Position_X  Position_Y  Position_Z       Length  SideLeft  SideRight  \
# 0     278.622162  191.004868  216.180954     0.000000  1.726921  11.332438
# 1     276.886230  190.995193  216.189209     1.736129  1.720277  11.336066
# 2     275.158936  190.985443  216.197693     3.463628  1.710446  11.338531
# 3     273.450806  190.975739  216.206207     5.171931  1.702247  11.341596
# 4     271.767700  190.966080  216.214584     6.855210  1.692779  11.343365
# ...          ...         ...         ...          ...       ...        ...
# 1087  287.037354  191.049957  216.144135  1711.757935  1.752758  11.311535
# 1088  285.413269  191.041183  216.150742  1713.382202  1.750256  11.315365
# 1089  283.757446  191.032700  216.158066  1715.038208  1.744066  11.320224
# 1090  282.069519  191.023926  216.165680  1716.726318  1.740213  11.325004
# 1091  280.354065  191.014389  216.172989  1718.441895  1.732845  11.328175
#
# ...

# %%
curvature = df.Radius * df.Direction

# %%
# Out:
# -0.033137447329182605
